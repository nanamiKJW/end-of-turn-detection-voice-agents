# %% [markdown]
# # 03 - Text Classifier Training
#
# This notebook trains the text-plus-metadata classifiers defined in `src/train_classifier.py`. It compares Logistic Regression, Random Forest, and Gradient Boosting.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

from train_classifier import train_and_compare, save_artifacts

data = pd.read_csv(PROJECT_ROOT / 'data' / 'sample_turns.csv')
best_name, best_model, metrics = train_and_compare(data)
metrics.round(3)

# %%
save_artifacts(best_model, metrics)
best_name

# %% [markdown]
# Because the dataset is synthetic, the model comparison should be interpreted as a pipeline demonstration rather than a real benchmark.
